# %%
# %matplotlib notebook
import seaborn
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import scipy.ndimage as ndimage
matplotlib.rcParams['figure.figsize'] = [8, 8]
from matplotlib.colors import LogNorm

# %%
# %run echelle.py
data = readData()

aMin = 0
aMax = 2e-4
aLen = 60
aList = np.linspace(aMin, aMax, aLen)

bMin = 0.0
bMax = 0.2
bLen = 80
bList = np.linspace(bMin, bMax, bLen)

cMin = -10
cMax = np.shape(data)[0]
cList = np.arange(cMin,cMax+1,1)

param_arrays = [aList, bList, cList]

x, all_ys  = extractOrders(data, param_arrays, cutoff_fraction=3, neighborhood_size=45)
# Out:
# Preprocessing
# Finding Peaks
# Performing Hough Transform on above values
# Percent: 0.0
# Percent: 10.0
# Percent: 20.0
# Percent: 30.0
# Percent: 40.0
# Percent: 50.0
# Percent: 60.0
# Percent: 70.0
# Percent: 80.0
# Percent: 90.0
# Performing Hough Transform on below values
# Percent: 0.0
# Percent: 10.0
# Percent: 20.0
# Percent: 30.0
# Percent: 40.0
# Percent: 50.0
# Percent: 60.0
# Percent: 70.0
# Percent: 80.0
# Percent: 90.0
# Seaching for Peaks
# Plotting
# /Users/nicholasmehrle/documents/science/codes/echelle/echelle.py:203: RuntimeWarning: invalid value encountered in less
#   y[y < 0]      = None

# %%
# plt.imshow(data,origin='lower',norm=LogNorm())
# half_width = 6.5
for above_y in all_ys[0]:
    plt.plot(x, above_y, 'r--')
for below_y in all_ys[1]:
    plt.plot(x, below_y, 'r--')

plt.imshow(data, origin='lower')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
np.max(above[0]-below[0])

# %%
#merge candidates
#IN PROGRESS
from scipy.spatial import cKDTree
ht_tree = cKDTree(ht_candidates)
cht_tree = cKDTree(cht_candidates)

# ht_to_fuse = ht_tree.query_pairs()
